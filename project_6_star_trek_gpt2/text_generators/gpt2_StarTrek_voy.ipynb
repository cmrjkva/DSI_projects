# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# TensorFlow 1.x selected.
# ...
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# !nvidia-smi
# Out:
# Mon Feb 22 22:14:19 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
gpt2.download_gpt2(model_name="355M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 308Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 4.10Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 369Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:35, 40.2Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 841Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 4.62Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 4.56Mit/s]

# %%
gpt2.mount_gdrive()
# Out:
# Mounted at /content/drive

# %%
file_name = 'full_voy.txt'

# %%
gpt2.copy_file_from_gdrive(file_name)

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='355M',
              steps=1000,
              restore_from='fresh',
              run_name='run3_StarTrek_voy',
              print_every=10,
              sample_every=200,
              save_every=500
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/355M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/355M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:07<00:00,  7.70s/it]
# dataset has 1758591 tokens
# Training...
# [10 | 24.04] loss=2.46 avg=2.46
# [20 | 39.74] loss=2.15 avg=2.30
# [30 | 55.78] loss=2.55 avg=2.39
# ...

# %%
gpt2.copy_checkpoint_to_gdrive(run_name='run3_StarTrek_voy')

# %%
text_startrek_voy = gpt2.generate(sess,
                              run_name='run3_StarTrek_voy',
                              length=500, prefix=' SWITCH ',
                              temperature=0.9, nsamples=10, batch_size=10, 
                              return_as_list=True)

# %%
with open('generated_text_startrek_voy.txt', 'w', encoding='utf-8') as f:
  f.writelines(text_startrek_voy)

# !cp generated_text_startrek_voy.txt /content/drive/MyDrive

# %%
text_startrek_voy[1]
# Out:
# " SWITCH \xa0(Realises he received the wrong colour version of the mirror.)\n\nTORRES: What's this?\n\nSEVEN:\xa0Blue\n\nKIM: I am surprised. I thought it was red!\n\nTORRES: Is that because all you see is red?\n\nSEVEN: All.\n\nDALA: You'll see it as it is.\n\nTORRES: Ok, but I will see it better now than I did the day I came here.\n\nSEVEN: I haven't been able to recreate what it is like to navigate through an\n\nhydroplaning duct.\n\nKES: I think it's a sign that you're experiencing some sort of panic disorder?\n\nSEVEN: That's impossible.\n\nDALA: What is happening? What's wrong?\n\nSEVEN: I am experiencing a dysphoria.\n\nKES: What is it?\n\nSEVEN: I don't know.\n\nKES: You're in pain.\n\nSEVEN: Yes. Yes.\n\nKES: What is it?\n\nDALA: It's terrible!\n\nKES: Tom. He's neck is full of bloody tissue.\n\nDALA: We burned it.\n\nSEVEN: How do I know?\n\nMILAN: I never saw it in your reflection.\n\nTORRES: You can't just tell me what to think.\n\nEveryone has this thing in their mind of
# ...
