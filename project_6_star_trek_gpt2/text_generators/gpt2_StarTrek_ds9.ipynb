# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# TensorFlow 1.x selected.
# ...
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# !nvidia-smi
# Out:
# Mon Feb 22 21:17:30 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
gpt2.download_gpt2(model_name="355M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 299Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 3.69Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 698Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:24, 57.2Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 603Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 3.97Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 5.44Mit/s]

# %%
gpt2.mount_gdrive()
# Out:
# Mounted at /content/drive

# %%
file_name = 'full_ds9.txt'

# %%
gpt2.copy_file_from_gdrive(file_name)

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='355M',
              steps=1000,
              restore_from='fresh',
              run_name='run3_StarTrek_ds9',
              print_every=10,
              sample_every=200,
              save_every=500
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/355M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/355M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:07<00:00,  7.27s/it]
# dataset has 1710210 tokens
# Training...
# [10 | 23.21] loss=2.32 avg=2.32
# [20 | 38.03] loss=2.24 avg=2.28
# [30 | 53.03] loss=2.10 avg=2.22
# ...

# %%
gpt2.copy_checkpoint_to_gdrive(run_name='run3_StarTrek_ds9')

# %%
text_startrek_ds9 = gpt2.generate(sess,
                              run_name='run3_StarTrek_ds9',
                              length=500, prefix=' SWITCH ',
                              temperature=0.9, nsamples=10, batch_size=10, 
                              return_as_list=True)

# %%
with open('generated_text_startrek_ds9.txt', 'w', encoding='utf-8') as f:
  f.writelines(text_startrek_ds9)

# !cp generated_text_startrek_ds9.txt /content/drive/MyDrive

# %%
text_startrek_ds9[1]
# Out:
# " SWITCH \n\n[Ops]\n\nSISKO: Ben, if you covered Archon material in your\n\njournal, please, I want to hear it.\n\nGARAK: The fundamental problem with Gul Dukat is that he is incapable of\n\ntaking responsibility for his actions -- for his crimes against Cardassia.\n\nSISKO: I have every confidence in you, Doctor.\n\nGARAK: You're right. Gul Dal had his chance and rejected it. He has\n\nit out, second, and he will not let anyone close to him put it in his\n\nback.\n\nSISKO: But General Martok is right. We cannot allow this man to be the next Defender of\n\nCardassia to take advantage of our people.\n\nGARAK: But Roden's just the man for the job. He's shown himself\n\nbeyond reproach. I demand that he be reinstated as the new Supreme Commander.\n\nSISKO: I don't want to rule over two million people!\n\nGARAK: Then why are you at the bomb?\n\nSISKO: Well, I've had enough of the cynicism. We have a responsibility\n\nto defend Cardassia. You are here to take the position of the Founders.
# ...
