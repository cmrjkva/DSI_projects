# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# TensorFlow 1.x selected.
# ...
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# !nvidia-smi
# Out:
# Tue Feb 23 00:10:04 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
gpt2.download_gpt2(model_name="355M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 299Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 4.12Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 362Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:24, 59.1Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 296Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 4.00Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 5.07Mit/s]

# %%
gpt2.mount_gdrive()
# Out:
# Mounted at /content/drive

# %%
file_name = 'full_ent.txt'

# %%
gpt2.copy_file_from_gdrive(file_name)

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='355M',
              steps=1000,
              restore_from='fresh',
              run_name='run3_StarTrek_ent',
              print_every=10,
              sample_every=200,
              save_every=500
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/355M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/355M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:03<00:00,  3.93s/it]
# dataset has 863833 tokens
# Training...
# [10 | 23.63] loss=2.18 avg=2.18
# [20 | 38.95] loss=2.23 avg=2.21
# [30 | 54.54] loss=2.32 avg=2.24
# ...

# %%
gpt2.copy_checkpoint_to_gdrive(run_name='run3_StarTrek_ent')

# %%
text_startrek_ent = gpt2.generate(sess,
                              run_name='run3_StarTrek_ent',
                              length=500, prefix=' SWITCH ',
                              temperature=0.9, nsamples=10, batch_size=10, 
                              return_as_list=True)

# %%
with open('generated_text_startrek_ent.txt', 'w', encoding='utf-8') as f:
  f.writelines(text_startrek_ent)

# !cp generated_text_startrek_ent.txt /content/drive/MyDrive

# %%
text_startrek_ent[1]
# Out:
# " SWITCH ?: Stop\n\n [Shuttlepod]\n\n TUCKER: (entering the outer hatch) The shuttlepod's locked down.\n\n [Launch bay]\n\n TRAVIS: The port hatch's open. I thought you were going to unlock it.\n\n [Shuttlepod]\n\n TRAVIS: I was about to but I know you're coming. So I'm just going to wait.\n\n [Launch bay]\n\n TRAVIS: The crew's not pleased with the way Enterprise is being run.\n\n [Shuttlepod]\n\n TRAVIS: We're going to have to shut down the reactor. If we don't do that, we'll be stuck with what's left.\n\n [Launch bay]\n\n TRAVIS: (steady on her feet and turns the controls) Hold it.\n\n [Shuttlepod]\n\n TRAVIS: Report. (She punches a hole in the door. More crewmen come out to see her.)\n\n [Shuttlepod]\n\n TRAVIS: I just pummelled that hatch with my boot.  Crewman: (he's been cut) Trav, Travis, get us out of here. (A) life support's here. (She latches on.)\n\n [Airponics]\n\n TRAVIS: I want to talk to you. (T'Pol enters.) T'POL: Captain?\n\nARCHER: You should want to watch.\n\nT'PO
# ...
