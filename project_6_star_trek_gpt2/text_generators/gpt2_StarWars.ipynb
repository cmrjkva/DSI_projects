# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# TensorFlow 1.x selected.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# !nvidia-smi
# Out:
# Mon Feb 22 17:43:02 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   63C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
gpt2.download_gpt2(model_name="355M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 223Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 3.23Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 689Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:27, 52.3Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 661Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 5.55Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 4.61Mit/s]

# %%
gpt2.mount_gdrive()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_name = 'full_SW.txt'

# %%
gpt2.copy_file_from_gdrive(file_name)

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='355M',
              steps=1000,
              restore_from='fresh',
              run_name='run3_StarWars',
              print_every=10,
              sample_every=200,
              save_every=500
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/355M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/355M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  3.27it/s]
# dataset has 53438 tokens
# Training...
# [10 | 24.34] loss=2.08 avg=2.08
# [20 | 40.25] loss=1.88 avg=1.98
# [30 | 56.47] loss=1.73 avg=1.90
# ...

# %%
gpt2.copy_checkpoint_to_gdrive(run_name='run3_StarWars')

# %%
text_starwars = gpt2.generate(sess,
                              run_name='run3_StarWars',
                              length=500, prefix=' SWITCH ',
                              temperature=0.9, nsamples=10, batch_size=10, 
                              return_as_list=True)

# %%
with open('generated_text_starwars.txt', 'w', encoding='utf-8') as f:
  f.writelines(text_starwars)

# !cp generated_text_starwars.txt /content/drive/MyDrive
