# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# TensorFlow 1.x selected.
# ...
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# !nvidia-smi
# Out:
# Mon Feb 22 20:33:57 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
gpt2.download_gpt2(model_name="355M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 255Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 4.93Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 445Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:33, 42.7Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 428Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 3.92Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 5.98Mit/s]

# %%
gpt2.mount_gdrive()
# Out:
# Mounted at /content/drive

# %%
file_name = 'full_TNG.txt'

# %%
gpt2.copy_file_from_gdrive(file_name)

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='355M',
              steps=1000,
              restore_from='fresh',
              run_name='run3_StarTrek_TNG',
              print_every=10,
              sample_every=200,
              save_every=500
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/355M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/355M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:07<00:00,  7.35s/it]
# dataset has 1624522 tokens
# Training...
# [10 | 24.35] loss=2.22 avg=2.22
# [20 | 39.98] loss=2.38 avg=2.30
# [30 | 56.02] loss=2.15 avg=2.25
# ...

# %%
gpt2.copy_checkpoint_to_gdrive(run_name='run3_StarTrek_TNG')

# %%
text_startrek_TNG = gpt2.generate(sess,
                              run_name='run3_StarTrek_TNG',
                              length=500, prefix=' SWITCH ',
                              temperature=0.9, nsamples=10, batch_size=10, 
                              return_as_list=True)

# %%
with open('generated_text_startrek_TNG.txt', 'w', encoding='utf-8') as f:
  f.writelines(text_startrek_TNG)

# !cp generated_text_startrek_TNG.txt /content/drive/MyDrive

# %%
text_startrek_TNG[1]
# Out:
# " SWITCH \n\nBuckman: There it is, the only one with the courage to put this ship\n\nand these brave men before death.\n\nLAFORGE: This is ridiculous. Captain, I'm sorry, but I can't stay here.\n\nBUCKMAN: You do not understand. I have no choice.\n\nLAFORGE: Try me.\n\nBUCKMAN: Maybe I can help.\n\nLAFORGE: I'm not okay. I do not belong here.\n\nBUCKMAN: I am not. I will be returned. I will be sent to Mynar to help\n\nVictor. And you will be there, all right?\n\nLAFORGE: Yes?\n\nBUCKMAN: You have set the good of this ship before your eyes.\n\nLAFORGE: Yes.\n\nBUCKMAN: Write it on my face.\n\nLAFORGE: Yes.\n\nWORF: Enterprise to Bridge. We are being hailed.\n\nWORF [OC]: Come in.\n\nBUCKMAN: Captain, I think it is time for me to step down.\n\nApparently the Captain doesn't appreciate the things I could have done\n\nright now.\n\nLAFORGE: Won't you be back, Father?\n\nBUCKMAN: I thought I would be back now, not on the Enterprise,\n\nyour ship, but on Mynar.\n\nLAFORGE: I see.\n\nBUCKMA
# ...
