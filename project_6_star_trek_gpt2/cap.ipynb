# %%
# !pip install tensorflow
# Out:
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# ...

# %%
import torch
# import pandas as pd
# from transformers import GPT2LMHeadModel, GPT2Tokenizer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-045dbcca8407> in <module>
# ----> 1 import torch
#       2 # import pandas as pd
#       3 # from transformers import GPT2LMHeadModel, GPT2Tokenizer
#
# ~\anaconda3\envs\gpt_env\lib\site-packages\torch\__init__.py in <module>
#     188     if USE_GLOBAL_DEPS:
#     189         _load_global_deps()
# --> 190     from torch._C import *
#     191
#     192 # Appease the type checker; ordinarily this binding is inserted by the
#
# ImportError: numpy.core.multiarray failed to import

# %%
star_trek = pd.read_json('./scripts/all_scripts_raw.json')

# %%
ds9_pilot = star_trek['DS9'][0]
tos_pilot = star_trek['TOS'][0]

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# %%
sequence = 'THe greatest question ever asked was'

# %%
inputs = tokenizer.encode(sequence, return_tensors='pt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4b8f51860dac> in <module>
# ----> 1 inputs = tokenizer.encode(sequence, return_tensors='pt')
#
# NameError: name 'tokenizer' is not defined

# %%
outputs = model.generate(inputs, max_length=10_252, do_sample=True, temperature=1.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c6bb4702d7b7> in <module>
# ----> 1 outputs = model.generate(inputs, max_length=10_252, do_sample=True, temperature=1.4)
#
# NameError: name 'model' is not defined

# %%
text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(text)
# Out:
# The Star Trek Transcripts - The Cage
#
#
#
# The
# Cage
# Unaired
# pilot
#
#
#
#
#
#
#  [Bridge]
#
# SPOCK: Check the circuit.
# TYLER: All operating, sir.
# SPOCK: It can't be the screen then. Definitely something out there,
# Captain, headed this way.
# TYLER: It could be these meteorites.
# ONE: No, it's something else. There's still something out there.
# TYLER: It's coming at the speed of light, collision course. The
# meteorite beam has not deflected it, Captain.
# ONE: Evasive manoeuvres, sir?
# PIKE: Steady as we go.
# GARISON: It's a radio wave, sir. We're passing through an old-style
# distress signal.
# PIKE: They were keyed to cause interference and attract attention this
# way.
# GARISON: A ship in trouble making a forced landing, sir. That's it. No
# other message.
# TYLER: I have a fix. It comes from the Talos star group.
# ONE: We've no ships or Earth colonies that far out.
# SPOCK: Their call letters check with a survey expedition. SS Columbia.
# ...
